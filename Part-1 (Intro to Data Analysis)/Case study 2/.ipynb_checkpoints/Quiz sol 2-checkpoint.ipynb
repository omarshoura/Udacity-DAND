# %%
import pandas as pd
import numpy as np
from scipy.stats import mode
from scipy.stats import stats

df_08=pd.read_csv('data_08_v3.csv')
df_18=pd.read_csv('data_18_v3.csv')
df_08.head();

# %%
df_08.dropna(inplace=True)

# %%
df_18.dropna(inplace=True)

# %%
df_18.cyl.astype('int');

# %%
# df_08.air_pollution_score.astype('float')
# query("air_pollution_score=='7/7'")

# %%
hp_08=df_08[df_08.fuel.str.contains('/')]
hp_18=df_18[df_18.fuel.str.contains('/')]
hp_18.head();

# %%
df_08_1=hp_08.copy()
df_08_2=hp_08.copy()
df_08_1.head();

# %%
split_columns=['fuel','air_pollution_score','city_mpg','hwy_mpg','cmb_mpg','greenhouse_gas_score']
for z in split_columns:
    df_08_1[z]=df_08_1[z].apply(lambda x: (x).split("/")[0])
    df_08_2[z]=df_08_2[z].apply(lambda x: (x).split("/")[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-96fb26c8ee79> in <module>
#       2 for z in split_columns:
#       3     df_08_1[z]=df_08_1[z].apply(lambda x: (x).split("/")[0])
# ----> 4     df_08_2[z]=df_08_2[z].apply(lambda x: (x).split("/")[1])
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-11-96fb26c8ee79> in <lambda>(x)
#       2 for z in split_columns:
#       3     df_08_1[z]=df_08_1[z].apply(lambda x: (x).split("/")[0])
# ...

# %%
df_08_2.head(5);

# %%
dfcolumns = pd.read_csv('data_08_v1.csv', nrows = 1)
df = pd.read_csv('data_08_v1.csv',
                  header = None,
                  skiprows = 1,
                  usecols = list(range(len(dfcolumns.columns))),
                  names = dfcolumns.columns)
df
# Out:
#             model  displ      cyl    trans drive      fuel sales_area stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...
